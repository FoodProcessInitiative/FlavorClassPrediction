# %% [markdown]
# <a href="https://colab.research.google.com/github/FoodProcessInitiative/FlavorClassPrediction/blob/main/spectrum3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import os
print(os.getcwd())      # 現在のディレクトリを取得
# Out:
# /content

# %% [markdown]
# prompt:
#
# Write code to load the next text file to numpy variable np_sp with numpy library. The file name is ‘onion0532-10s10t.txt’ in my drive > Colab Notebooks.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# Adjust the path to where your file is located in Google Drive
fn = 'onion0532-10s10t.txt'
file_path = '/content/drive/MyDrive/Colab Notebooks/' + fn
np_SP = np.loadtxt(file_path)
print(np_SP[:5])   #print first 5 elements of np_SP
# Out:
# [[   49.8789 18478.5   ]
#  [   53.6324 18497.3   ]
#  [   57.3823 18516.8   ]
#  [   61.1306 18537.    ]
#  [   64.8796 18557.4   ]]

# %% [markdown]
# prompt:
#
# The numpy variable np_SP has wn in the first column and spectrum intensity in the second column. Write code that divides the wn and intensity columns into np_wn and np1.

# %%
#split np_SP into np_WN and np1
np_WN = np_SP[:, 0]
np1 = np_SP[:, 1]

# %%
#Install Raman spectrum libraly
# !pip install git+https://github.com/FoodProcessInitiative/mypkg.git
#!pip install git+https://github.com/FoodProcessInitiative/mypkg.git --force-reinstall #When you update a GitHub repository, use the --force-reinstall flag.
# Out:
# ...
#   Cloning https://github.com/FoodProcessInitiative/mypkg.git to /tmp/pip-req-build-24520hh3
#   Running command git clone --filter=blob:none --quiet https://github.com/FoodProcessInitiative/mypkg.git /tmp/pip-req-build-24520hh3
#   Resolved https://github.com/FoodProcessInitiative/mypkg.git to commit 9f1082c323547138d7ff9d31bf3d3c9c4a3702c9
#   Preparing metadata (setup.py) ... done
# ...

# %%
from mypkg.utilSP import * # mypkg.utilis モジュールから plot_SP 関数をインポート

# %%
plot_SP(np_WN, np1,fn)   #plot spectrum

# %%
w1id,w2id = WNid(np_WN,300,2000)  #w1id,w2idはindex　(np_WN,left end WN,right end WN)
#sliced spectrum
np_WN2 = np_WN[w1id:w2id]
np1_2 = np1[w1id:w2id]
plot_SP(np_WN2, np1_2,fn+'  sliced spectrum')

# %%
np_peak = p_pick(np1_2,200,5) #(npa,ndiv=100,thrddiv=10) Increasing ndiv or thrddiv increases the number of peaks.

# %%
print('Wavenumbers Peak value')
for i in range(len(np_peak)):
    print(np_WN2[int(np_peak[i,0])],np_peak[i,1])
# Out:
# Wavenumbers Peak value
# 327.136 4414.26
# 341.69 4418.63
# 348.958 4438.29
# 363.477 4403.02
# 370.728 4382.94
# 381.593 4396.12
# 388.829 4392.3
# 421.324 4850.54
# 521.674 4668.07
# 582.062 4052.96
# 596.213 4090.64
# 627.968 4301.4
# 663.122 3554.56
# 677.145 3523.61
# 687.647 3525.63
# 708.617 3595.61
# 753.88 3451.93
# 785.082 3506.38
# 795.457 3492.16
# 823.069 3822.2
# 871.181 3818.47
# 898.557 3675.93
# 922.442 3733.67
# 946.263 3494.72
# 966.629 3679.28
# 980.179 3601.08
# 1003.84 3429.35
# 1013.97 3442.89
# 1067.76 4215.99
# 1084.5 4314.31
# 1121.22 3897.24
# 1266.56 3672.09
# 1309.03 3496.06
# 1341.57 3592.88
# 1348.06 3609.49
# 1364.27 3604.74
# 1370.74 3622.29
# 1399.82 3615.17
# 1412.71 3659.48
# 1419.15 3658.06
# 1438.44 3618.11
# 1460.88 4035.84
# 1553.25 3460.38
# 1619.51 4090.77
# 1638.34 4227.01
# 1657.14 4143.71
